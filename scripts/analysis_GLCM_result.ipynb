# %%
import pandas as pd

# %%
# Load the CSVs for different percentages (if available)
path_susu_100 = "D:\SEMESTER5\PCD\proyek_image_processing_susu\output\glcm_results\susu_100_glcm_result.csv"  # This would be the path to the dataset
path_susu_90 = "D:\SEMESTER5\PCD\proyek_image_processing_susu\output\glcm_results\susu_90_glcm_result.csv"
path_susu_80 = "D:\SEMESTER5\PCD\proyek_image_processing_susu\output\glcm_results\susu_80_glcm_result.csv"
path_susu_70 = "D:\SEMESTER5\PCD\proyek_image_processing_susu\output\glcm_results\susu_70_glcm_result.csv"
path_susu_60 = "D:\SEMESTER5\PCD\proyek_image_processing_susu\output\glcm_results\susu_60_glcm_result.csv"

# Reading the data assuming they follow the same structure
df_susu_100 = pd.read_csv(path_susu_100)
df_susu_90 = pd.read_csv(path_susu_90)
df_susu_80 = pd.read_csv(path_susu_80)
df_susu_70 = pd.read_csv(path_susu_70)
df_susu_60 = pd.read_csv(path_susu_60)

# %%
df_susu_100.describe()
# Out:
#            mean_R      mean_G      mean_B  contrast_R  dissimilarity_R  \
# count   10.000000   10.000000   10.000000   10.000000        10.000000
# mean   198.321942  188.570785  171.397951    0.099836         0.086837
# std      4.255066    4.707465    4.299504    0.028461         0.024216
# min    190.921223  179.540466  162.474450    0.066974         0.064416
# 25%    195.911405  185.979058  169.500283    0.080312         0.070044
# 50%    200.316730  190.839672  173.115918    0.093971         0.081661
# 75%    201.018862  191.282317  173.858255    0.115071         0.094201
# max    202.733305  193.260956  175.757198    0.160046         0.144168
#
#        homogeneity_R   energy_R  correlation_R      asm_R  entropy_R  ...  \
# count      10.000000  10.000000      10.000000  10.000000  10.000000  ...
# mean        0.957796   0.484527       0.994338   0.236026  11.563213  ...
# std         0.011847   0.037190       0.001562   0.034125   0.803726  ...
# min         0.929419   0.395559       0.990966   0.156492  10.842891  ...
# 25%         0.954830   0.485842       0.993594   0.236059  11.109973  ...
# 50%         0.959949   0.494371       0.994581   0.244421  11.284540  ...
# 75%         0.966155   0.502813       0.995190   0.252837  11.599657  ...
# max         0.969216   0.525931       0.996192   0.276628  13.586664  ...
#
#        correlation_G      asm_G  entropy_G  contrast_B  dissimilarity_B  \
# count      10.000000  10.000000  10.000000   10.000000        10.000000
# mean        0.994263   0.189389  12.333502    0.080540         0.067949
# std         0.001491   0.020838   0.614073    0.026739         0.019277
# min         0.991544   0.147724  11.713784    0.042414         0.041683
# 25%         0.993564   0.179817  11.818799    0.055297         0.050756
# 50%         0.994062   0.184619  12.304352    0.088948         0.071084
# 75%         0.995442   0.209441  12.554622    0.094737         0.076273
# max         0.996459   0.214060  13.724192    0.114539         0.099429
#
#        homogeneity_B   energy_B  correlation_B      asm_B  entropy_B
# count      10.000000  10.000000      10.000000  10.000000  10.000000
# mean        0.967203   0.439006       0.994084   0.193040  12.162647
# std         0.008992   0.018532       0.001957   0.016002   0.574394
# min         0.951721   0.403693       0.991549   0.162975  11.500074
# 25%         0.963395   0.426245       0.992950   0.181732  11.685772
# 50%         0.966148   0.446773       0.993582   0.199610  11.946291
# 75%         0.975072   0.452915       0.995891   0.205136  12.684910
# max         0.979232   0.455562       0.996969   0.207540  13.033774
#
# [8 rows x 24 columns]

# %%
df_susu_100
# Out:
#        filename      mean_R      mean_G      mean_B  contrast_R  \
# 0   sampel1.png  195.361081  185.103429  168.760816    0.079351
# 1  sampel10.png  200.778874  191.184115  173.117981    0.123627
# 2   sampel2.png  197.562377  188.605946  171.718686    0.091237
# 3   sampel3.png  191.856533  182.182458  166.126490    0.096706
# 4   sampel4.png  190.921223  179.540466  162.474450    0.160046
# 5   sampel5.png  201.098857  191.311672  173.933169    0.116854
# 6   sampel6.png  202.273714  192.829324  175.343346    0.083194
# 7   sampel7.png  200.671492  191.194252  173.633513    0.066974
# 8   sampel8.png  202.733305  193.260956  175.757198    0.070654
# 9   sampel9.png  199.961967  190.495229  173.113856    0.109721
#
#    dissimilarity_R  homogeneity_R  energy_R  correlation_R     asm_R  ...  \
# 0         0.064416       0.969216  0.504474       0.995099  0.254496  ...
# 1         0.105816       0.948757  0.497831       0.993179  0.247861  ...
# 2         0.070855       0.966473  0.491130       0.994703  0.241211  ...
# 3         0.080658       0.961177  0.448154       0.994460  0.200850  ...
# 4         0.144168       0.929419  0.395559       0.990966  0.156492  ...
# 5         0.096396       0.953708  0.484732       0.993495  0.234979  ...
# 6         0.082664       0.958721  0.525931       0.995220  0.276628  ...
# 7         0.066007       0.967093  0.497612       0.996180  0.247632  ...
# 8         0.069774       0.965201  0.510679       0.996192  0.260810  ...
# 9         0.087616       0.958198  0.489171       0.993890  0.239299  ...
#
#    correlation_G     asm_G  entropy_G  contrast_B  dissimilarity_B  \
# 0       0.994032  0.212865  11.713784    0.091688         0.077184
# 1       0.993183  0.186587  12.491927    0.086209         0.069171
# 2       0.994195  0.199172  12.022355    0.107798         0.087884
# 3       0.994091  0.177293  12.718243    0.084605         0.069050
# 4       0.991544  0.147724  13.724192    0.114539         0.099429
# 5       0.993509  0.179299  12.575521    0.092944         0.072998
# 6       0.995858  0.212864  11.750947    0.044337         0.043891
# 7       0.996033  0.182651  12.160957    0.045528         0.044658
# 8       0.996459  0.214060  11.729349    0.042414         0.041683
# 9       0.993727  0.181372  12.447747    0.095335         0.073538
#
#    homogeneity_B  energy_B  correlation_B     asm_B  entropy_B
# 0       0.962789  0.403693       0.992888  0.162975  12.875018
# 1       0.967013  0.455554       0.993808  0.207533  11.832690
# 2       0.957915  0.437368       0.992034  0.191298  12.521313
# 3       0.966937  0.416208       0.993925  0.173232  12.739442
# 4       0.951721  0.422537       0.991549  0.178543  13.033774
# 5       0.965359  0.452557       0.993356  0.204810  11.970761
# 6       0.978099  0.447507       0.996629  0.200267  11.594774
# 7       0.977758  0.455562       0.996547  0.207540  11.500074
# 8       0.979232  0.446038       0.996969  0.198954  11.636800
# 9       0.965211  0.453035       0.993133  0.205244  11.921821
#
# [10 rows x 25 columns]

# %%
def process_dataframe(df):
    """Drop non-numeric columns and compute the mean of the remaining columns."""
    df_numeric = df.drop(columns=['filename'])  # Dropping the 'filename' column
    return df_numeric.mean()  # Returning the mean of each column

# Process all the sample dataframes
mean_100 = process_dataframe(df_susu_100)
mean_90 = process_dataframe(df_susu_90)
mean_80 = process_dataframe(df_susu_80)
mean_70 = process_dataframe(df_susu_70)
mean_60 = process_dataframe(df_susu_60)

# Combine all the means into a single dataframe
mean_df = pd.DataFrame({
    'susu_100%': mean_100,
    'susu_90%': mean_90,
    'susu_80%': mean_80,
    'susu_70%': mean_70,
    'susu_60%': mean_60
})

mean_df
# Out:
#                   susu_100%    susu_90%    susu_80%    susu_70%    susu_60%
# mean_R           198.321942  200.362389  190.281533  183.554983  182.614858
# mean_G           188.570785  191.428230  179.243229  172.543215  171.684924
# mean_B           171.397951  174.641913  161.309117  154.698541  152.283402
# contrast_R         0.099836    0.103631    0.085488    0.100092    0.123414
# dissimilarity_R    0.086837    0.090382    0.071167    0.088975    0.112113
# homogeneity_R      0.957796    0.956061    0.965788    0.956579    0.945035
# energy_R           0.484527    0.469405    0.523040    0.441523    0.504014
# correlation_R      0.994338    0.994269    0.995501    0.994130    0.992702
# asm_R              0.236026    0.220856    0.273626    0.195018    0.254369
# entropy_R         11.563213   11.728051   11.431276   12.314604   11.463251
# contrast_G         0.095659    0.099473    0.085154    0.099708    0.125216
# dissimilarity_G    0.082541    0.085970    0.070615    0.088552    0.113587
# homogeneity_G      0.959955    0.958290    0.966085    0.956793    0.944331
# energy_G           0.434563    0.427011    0.522033    0.426356    0.495864
# correlation_G      0.994263    0.994188    0.995220    0.993751    0.991792
# asm_G              0.189389    0.182579    0.272636    0.181847    0.246345
# entropy_G         12.333502   12.491704   11.589597   12.718164   11.664051
# contrast_B         0.080540    0.086413    0.090260    0.116003    0.098592
# dissimilarity_B    0.067949    0.073256    0.075693    0.105294    0.087222
# homogeneity_B      0.967203    0.964615    0.963550    0.948379    0.957488
# energy_B           0.439006    0.437161    0.453239    0.381218    0.514916
# correlation_B      0.994084    0.993721    0.993978    0.991248    0.991630
# asm_B              0.193040    0.191154    0.205998    0.145499    0.265273
# entropy_B         12.162647   12.205016   12.385047   13.665455   10.991363

# %%
# mengambil standar deviasi dari masing-masing data
def process_dataframe2(df):
    """Drop non-numeric columns and compute the mean of the remaining columns."""
    df_numeric = df.drop(columns=['filename'])  # Dropping the 'filename' column
    return df_numeric.std()  # Returning the mean of each column

# Process all the sample dataframes
std_100 = process_dataframe2(df_susu_100)
std_90 = process_dataframe2(df_susu_90)
std_80 = process_dataframe2(df_susu_80)
std_70 = process_dataframe2(df_susu_70)
std_60 = process_dataframe2(df_susu_60)

# Combine all the means into a single dataframe
std_df = pd.DataFrame({
    'susu_100%': std_100,
    'susu_90%': std_90,
    'susu_80%': std_80,
    'susu_70%': std_70,
    'susu_60%': std_60
})
std_df
# Out:
#                  susu_100%  susu_90%  susu_80%  susu_70%  susu_60%
# mean_R            4.255066  0.818364  0.529100  0.468247  0.211070
# mean_G            4.707465  0.856651  0.659857  0.473426  0.176845
# mean_B            4.299504  0.824180  0.945969  0.387147  0.171709
# contrast_R        0.028461  0.026069  0.002689  0.025597  0.030505
# dissimilarity_R   0.024216  0.020460  0.002181  0.022587  0.030241
# homogeneity_R     0.011847  0.009764  0.001051  0.011023  0.015096
# energy_R          0.037190  0.023641  0.007673  0.008676  0.018989
# correlation_R     0.001562  0.001344  0.000175  0.001437  0.001776
# asm_R             0.034125  0.022981  0.008023  0.007639  0.018943
# entropy_R         0.803726  0.490226  0.152815  0.400459  0.518388
# contrast_G        0.025042  0.026606  0.002361  0.025433  0.031851
# dissimilarity_G   0.018815  0.020711  0.002345  0.022396  0.031603
# homogeneity_G     0.008946  0.009862  0.001187  0.010925  0.015779
# energy_G          0.024330  0.016011  0.011388  0.008224  0.022307
# correlation_G     0.001491  0.001455  0.000163  0.001521  0.002061
# asm_G             0.020838  0.013974  0.011906  0.006994  0.021941
# entropy_G         0.614073  0.421333  0.224996  0.406996  0.545611
# contrast_B        0.026739  0.026719  0.004553  0.031143  0.020754
# dissimilarity_B   0.019277  0.020709  0.004208  0.028716  0.020375
# homogeneity_B     0.008992  0.009837  0.002078  0.014143  0.010152
# energy_B          0.018532  0.006618  0.025074  0.013243  0.011931
# correlation_B     0.001957  0.001816  0.000240  0.002244  0.001711
# asm_B             0.016002  0.005780  0.022622  0.010026  0.012238
# entropy_B         0.574394  0.370041  0.385588  0.479788  0.405488

# %%
mean_df.to_csv("D:\SEMESTER5\PCD\proyek_image_processing_susu\output\glcm_results\mean_glcm_results.csv")  # Save the combined dataframe to a CSV file

# %%
import os
# Tentukan folder tempat menyimpan gambar
output_folder = "D:\SEMESTER5\PCD\proyek_image_processing_susu\output\plots_GLCM_new"  # Ganti dengan path folder tujuan

# Buat folder jika belum ada
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the top-level categories (grouped labels) and their respective subcategories
concentrations = ['Fresh (Susu 100%)', 'Campuran (Susu 90%)', 'Campuran (Susu 80%)', 'Campuran (Susu 70%)', 'Campuran (Susus 60%)']
channels = ['Blue', 'Green', 'Red']

# The number of channels per concentration level
n_channels = len(channels)

# Offset untuk setiap kelompok bar
offset = 0.2

# Flatten the x-axis labels to create a list of repeated color channels under each concentration
x_labels = [f"{channel}" for _ in concentrations for channel in channels]

# Create tick positions for both levels
tick_positions = np.arange(len(x_labels))

# Extract the feature data for each color channel and percentage
contrast_blue = mean_df.loc['contrast_B']
contrast_green = mean_df.loc['contrast_G']
contrast_red = mean_df.loc['contrast_R']

homogeneity_blue = mean_df.loc['homogeneity_B']
homogeneity_green = mean_df.loc['homogeneity_G']
homogeneity_red = mean_df.loc['homogeneity_R']

disimilarity_blue = mean_df.loc['dissimilarity_B']
disimilarity_green = mean_df.loc['dissimilarity_G']
disimilarity_red = mean_df.loc['dissimilarity_R']

energy_blue = mean_df.loc['energy_B']
energy_green = mean_df.loc['energy_G']
energy_red = mean_df.loc['energy_R']

correlation_blue = mean_df.loc['correlation_B']
correlation_green = mean_df.loc['correlation_G']
correlation_red = mean_df.loc['correlation_R']

entropy_blue = mean_df.loc['entropy_B']
entropy_green = mean_df.loc['entropy_G']
entropy_red = mean_df.loc['entropy_R']

# Combine the channels for Contrast and Homogeneity
contrast = [contrast_blue[0], contrast_green[0], contrast_red[0],
            contrast_blue[1], contrast_green[1], contrast_red[1],
            contrast_blue[2], contrast_green[2], contrast_red[2],
            contrast_blue[3], contrast_green[3], contrast_red[3],
            contrast_blue[4], contrast_green[4], contrast_red[4]]

homogeneity = [homogeneity_blue[0], homogeneity_green[0], homogeneity_red[0],
               homogeneity_blue[1], homogeneity_green[1], homogeneity_red[1],
               homogeneity_blue[2], homogeneity_green[2], homogeneity_red[2],
               homogeneity_blue[3], homogeneity_green[3], homogeneity_red[3],
               homogeneity_blue[4], homogeneity_green[4], homogeneity_red[4]]

disimilarity = [disimilarity_blue[0], disimilarity_green[0], disimilarity_red[0],
                disimilarity_blue[1], disimilarity_green[1], disimilarity_red[1],
                disimilarity_blue[2], disimilarity_green[2], disimilarity_red[2],
                disimilarity_blue[3], disimilarity_green[3], disimilarity_red[3],
                disimilarity_blue[4], disimilarity_green[4], disimilarity_red[4]]

energy = [energy_blue[0], energy_green[0], energy_red[0],
            energy_blue[1], energy_green[1], energy_red[1],
            energy_blue[2], energy_green[2], energy_red[2],
            energy_blue[3], energy_green[3], energy_red[3],
            energy_blue[4], energy_green[4], energy_red[4]]

correlation = [correlation_blue[0], correlation_green[0], correlation_red[0],
                correlation_blue[1], correlation_green[1], correlation_red[1],
                correlation_blue[2], correlation_green[2], correlation_red[2],
                correlation_blue[3], correlation_green[3], correlation_red[3],
                correlation_blue[4], correlation_green[4], correlation_red[4]]

entropy = [entropy_blue[0], entropy_green[0], entropy_red[0],
            entropy_blue[1], entropy_green[1], entropy_red[1],
            entropy_blue[2], entropy_green[2], entropy_red[2],
            entropy_blue[3], entropy_green[3], entropy_red[3],
            entropy_blue[4], entropy_green[4], entropy_red[4]]
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:46: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   contrast = [contrast_blue[0], contrast_green[0], contrast_red[0],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:47: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   contrast_blue[1], contrast_green[1], contrast_red[1],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:48: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   contrast_blue[2], contrast_green[2], contrast_red[2],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:49: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   contrast_blue[3], contrast_green[3], contrast_red[3],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:50: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   contrast_blue[4], contrast_green[4], contrast_red[4]]
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:52: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   homogeneity = [homogeneity_blue[0], homogeneity_green[0], homogeneity_red[0],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:53: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   homogeneity_blue[1], homogeneity_green[1], homogeneity_red[1],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:54: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   homogeneity_blue[2], homogeneity_green[2], homogeneity_red[2],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:55: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   homogeneity_blue[3], homogeneity_green[3], homogeneity_red[3],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:56: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   homogeneity_blue[4], homogeneity_green[4], homogeneity_red[4]]
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:58: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   disimilarity = [disimilarity_blue[0], disimilarity_green[0], disimilarity_red[0],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:59: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   disimilarity_blue[1], disimilarity_green[1], disimilarity_red[1],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:60: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   disimilarity_blue[2], disimilarity_green[2], disimilarity_red[2],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:61: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   disimilarity_blue[3], disimilarity_green[3], disimilarity_red[3],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:62: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   disimilarity_blue[4], disimilarity_green[4], disimilarity_red[4]]
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:64: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   energy = [energy_blue[0], energy_green[0], energy_red[0],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:65: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   energy_blue[1], energy_green[1], energy_red[1],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:66: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   energy_blue[2], energy_green[2], energy_red[2],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:67: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   energy_blue[3], energy_green[3], energy_red[3],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:68: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   energy_blue[4], energy_green[4], energy_red[4]]
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:70: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   correlation = [correlation_blue[0], correlation_green[0], correlation_red[0],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   correlation_blue[1], correlation_green[1], correlation_red[1],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   correlation_blue[2], correlation_green[2], correlation_red[2],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:73: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   correlation_blue[3], correlation_green[3], correlation_red[3],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:74: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   correlation_blue[4], correlation_green[4], correlation_red[4]]
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:76: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   entropy = [entropy_blue[0], entropy_green[0], entropy_red[0],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   entropy_blue[1], entropy_green[1], entropy_red[1],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:78: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   entropy_blue[2], entropy_green[2], entropy_red[2],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:79: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   entropy_blue[3], entropy_green[3], entropy_red[3],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\1098887442.py:80: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   entropy_blue[4], entropy_green[4], entropy_red[4]]

# %%
# Tentukan nama file gambar
file_name = "contrast_susu_murni_sampai_campuran.png"  # Ganti dengan nama file yang diinginkan

# Gabungkan folder dengan nama file untuk mendapatkan path lengkap
output_path = os.path.join(output_folder, file_name)

plt.figure(figsize=(12, 4))
plt.plot(tick_positions, contrast, label='Contrast', marker='o', color='blue')
plt.title('Contrast Susu Murni Sampai Campuran di Setiap Model RGB')
plt.ylabel('Average Values')
plt.grid(True)
plt.xticks(tick_positions, x_labels, rotation=0)
for i, concentration in enumerate(concentrations):
    plt.text(i * n_channels + 1, plt.ylim()[1] - 0.055, concentration, ha='center', va='top', fontsize=10, fontweight='bold')
for i in range(1, len(concentrations)):
    plt.axvline(x=i * n_channels - 0.5, color='black', linestyle='--', lw=1)
plt.legend(loc='center right')
plt.tight_layout()

# Simpan plot ke dalam file
plt.savefig(output_path, dpi=400)

plt.show()

# %%
# Tentukan nama file gambar
file_name = "homogeneity_susu_murni_sampai_campuran.png"  # Ganti dengan nama file yang diinginkan

# Gabungkan folder dengan nama file untuk mendapatkan path lengkap
output_path = os.path.join(output_folder, file_name)

plt.figure(figsize=(12, 4))
plt.plot(tick_positions, homogeneity, label='Homogeneity', marker='o', color='green')
plt.title('Homogeneity Susu Murni Sampai Campuran di Setiap Model RGB')
plt.ylabel('Average Values')
plt.grid(True)
plt.xticks(tick_positions, x_labels, rotation=0)
for i, concentration in enumerate(concentrations):
    plt.text(i * n_channels + 1, plt.ylim()[0] - 0.0035, concentration, ha='center', va='top', fontsize=10, fontweight='bold')
for i in range(1, len(concentrations)):
    plt.axvline(x=i * n_channels - 0.5, color='black', linestyle='--', lw=1)
plt.legend(loc='center right')
plt.tight_layout()

#simpan gambar
plt.savefig(output_path, dpi=400)

plt.show()

# %%
# Tentukan nama file gambar
file_name = 'disimilarity_susu_murni_sampai_campuran.png'

# Gabungkan folder dengan nama file untuk mendapatkan path lengkap
output_path = os.path.join(output_folder, file_name)

plt.figure(figsize=(12, 4))
plt.plot(tick_positions, disimilarity, label='Disimilarity', marker='o', color='red')
plt.title('Dissimilarity Susu Murni Sampai Campuran di Setiap Model RGB')
plt.ylabel('Average Values')
plt.grid(True)
plt.xticks(tick_positions, x_labels, rotation=0)
for i, concentration in enumerate(concentrations):
    plt.text(i * n_channels + 1, plt.ylim()[1] - 0.058, concentration, ha='center', va='top', fontsize=10, fontweight='bold')
for i in range(1, len(concentrations)):
    plt.axvline(x=i * n_channels - 0.5, color='black', linestyle='--', lw=1)
plt.legend(loc='center right')
plt.tight_layout()


# Simpan plot ke dalam file
plt.savefig(output_path, dpi=400)

plt.show()

# %%
# Tentukan nama file gambar
file_name = 'correlation_susu_murni_sampai_campuran.png'

# Gabungkan folder dengan nama file untuk mendapatkan path lengkap
output_path = os.path.join(output_folder, file_name)

plt.figure(figsize=(12, 4))
plt.plot(tick_positions, correlation, label='Correlation', marker='o', color='purple')
plt.title('Correlation Susu Murni Sampai Campuran di Setiap Model RGB')
plt.ylabel('Average Values')
plt.grid(True)
plt.xticks(tick_positions, x_labels, rotation=0)
for i, concentration in enumerate(concentrations):
    plt.text(i * n_channels + 1, plt.ylim()[1] - 0.0054, concentration, ha='center', va='top', fontsize=10, fontweight='bold')
for i in range(1, len(concentrations)):
    plt.axvline(x=i * n_channels - 0.5, color='black', linestyle='--', lw=1)
plt.legend(loc='center right')
plt.tight_layout()

# Simpan plot ke dalam file
plt.savefig(output_path, dpi=400)

plt.show()

# %%
# Tentukan nama file gambar
file_name = "energy_susu_murni_sampai_campuran_rgb.png"  # Ganti dengan nama file yang diinginkan

# Gabungkan folder dengan nama file untuk mendapatkan path lengkap
output_path = os.path.join(output_folder, file_name)


plt.figure(figsize=(12, 4))
plt.plot(tick_positions, energy, label='Energy', marker='o', color='orange')
plt.title('Energy Susu Murni Sampai Campuran di Setiap Model RGB')
plt.ylabel('Average Values')
plt.grid(True)
plt.xticks(tick_positions, x_labels, rotation=0)
for i, concentration in enumerate(concentrations):
    plt.text(i * n_channels + 1, plt.ylim()[1] - 0.18, concentration, ha='center', va='top', fontsize=10, fontweight='bold')
for i in range(1, len(concentrations)):
    plt.axvline(x=i * n_channels - 0.5, color='black', linestyle='--', lw=1)
plt.legend(loc='center right')
plt.tight_layout()

# simpan gambar ke dalam file
plt.savefig(output_path, dpi=400)

plt.show()

# %%
# Tentukan nama file gambar
file_name = "entropy_susu_murni_sampai_campuran_rgb.png"  # Ganti dengan nama file yang diinginkan

# Gabungkan folder dengan nama file untuk mendapatkan path lengkap
output_path = os.path.join(output_folder, file_name)

plt.figure(figsize=(12, 4))
plt.plot(tick_positions, entropy, label='Entropy', marker='o', color='brown')
plt.title('Entropy Susu Murni Sampai Campuran di Setiap Model RGB')
plt.ylabel('Average Values')
plt.grid(True)
plt.xticks(tick_positions, x_labels, rotation=0)
for i, concentration in enumerate(concentrations):
    plt.text(i * n_channels + 1, plt.ylim()[0] - 0.4, concentration, ha='center', va='top', fontsize=10, fontweight='bold')
for i in range(1, len(concentrations)):
    plt.axvline(x=i * n_channels - 0.5, color='black', linestyle='--', lw=1)
plt.legend(loc='center right')
plt.tight_layout()

# Simpan plot ke dalam file
plt.savefig(output_path, dpi=400)

plt.show()

# %%
# import matplotlib.pyplot as plt

# # Define the categories for x-axis
# categories = ['Fresh (100%)', 'Campuran (90%)', 'Campuran (80%)', 'Campuran (70%)', 'Campuran (60%)']

# # Extract the feature data for each percentage from the mean_df
# contrast = mean_df.loc['contrast_R']
# homogeneity = mean_df.loc['homogeneity_R']
# energy = mean_df.loc['energy_R']
# correlation = mean_df.loc['correlation_R']

# # Plotting Contrast
# plt.figure(figsize=(10, 6))

# plt.subplot(2, 1, 1)
# plt.plot(categories, contrast, label='Contrast', marker='o', color='blue')
# plt.title('Contrast red')
# plt.ylabel('Average Values')
# plt.grid(True)

# # Plotting Homogeneity
# plt.subplot(2, 1, 2)
# plt.plot(categories, homogeneity, label='Homogeneity', marker='o', color='orange')
# plt.title('Homogeneity red')
# plt.ylabel('Average Values')
# plt.grid(True)

# plt.tight_layout()
# plt.show()

# # You can repeat similar steps for other features like Energy and Correlation

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the top-level categories (grouped labels) and their respective subcategories
concentrations = ['Fresh (Susu 100%)', 'Campuran (Susu 90%)', 'Campuran (Susu 80%)', 'Campuran (Susu 70%)', 'Campuran (Susus 60%)']
channels = ['Blue', 'Green', 'Red']

# The number of channels per concentration level
n_channels = len(channels)

# Offset untuk setiap kelompok bar
offset = 0.2

# Flatten the x-axis labels to create a list of repeated color channels under each concentration
x_labels = [f"{channel}" for _ in concentrations for channel in channels]

# Create tick positions for both levels
tick_positions = np.arange(len(x_labels))

# Extract the feature data for each color channel and percentage
contrast_blue = std_df.loc['contrast_B']
contrast_green = std_df.loc['contrast_G']
contrast_red = std_df.loc['contrast_R']

homogeneity_blue = std_df.loc['homogeneity_B']
homogeneity_green = std_df.loc['homogeneity_G']
homogeneity_red = std_df.loc['homogeneity_R']

# disimilarity_blue = std_df.loc['dissimilarity_B']
# disimilarity_green = std_df.loc['dissimilarity_G']
# disimilarity_red = std_df.loc['dissimilarity_R']

energy_blue = std_df.loc['energy_B']
energy_green = std_df.loc['energy_G']
energy_red = std_df.loc['energy_R']

correlation_blue = std_df.loc['correlation_B']
correlation_green = std_df.loc['correlation_G']
correlation_red = std_df.loc['correlation_R']

# entropy_blue = std_df.loc['entropy_B']
# entropy_green = std_df.loc['entropy_G']
# entropy_red = std_df.loc['entropy_R']

# Combine the channels for Contrast and Homogeneity
std_contrast = [contrast_blue[0], contrast_green[0], contrast_red[0],
            contrast_blue[1], contrast_green[1], contrast_red[1],
            contrast_blue[2], contrast_green[2], contrast_red[2],
            contrast_blue[3], contrast_green[3], contrast_red[3],
            contrast_blue[4], contrast_green[4], contrast_red[4]]

std_homogeneity = [homogeneity_blue[0], homogeneity_green[0], homogeneity_red[0],
               homogeneity_blue[1], homogeneity_green[1], homogeneity_red[1],
               homogeneity_blue[2], homogeneity_green[2], homogeneity_red[2],
               homogeneity_blue[3], homogeneity_green[3], homogeneity_red[3],
               homogeneity_blue[4], homogeneity_green[4], homogeneity_red[4]]

# disimilarity = [disimilarity_blue[0], disimilarity_green[0], disimilarity_red[0],
#                 disimilarity_blue[1], disimilarity_green[1], disimilarity_red[1],
#                 disimilarity_blue[2], disimilarity_green[2], disimilarity_red[2],
#                 disimilarity_blue[3], disimilarity_green[3], disimilarity_red[3],
#                 disimilarity_blue[4], disimilarity_green[4], disimilarity_red[4]]

std_energy = [energy_blue[0], energy_green[0], energy_red[0],
            energy_blue[1], energy_green[1], energy_red[1],
            energy_blue[2], energy_green[2], energy_red[2],
            energy_blue[3], energy_green[3], energy_red[3],
            energy_blue[4], energy_green[4], energy_red[4]]

std_correlation = [correlation_blue[0], correlation_green[0], correlation_red[0],
                correlation_blue[1], correlation_green[1], correlation_red[1],
                correlation_blue[2], correlation_green[2], correlation_red[2],
                correlation_blue[3], correlation_green[3], correlation_red[3],
                correlation_blue[4], correlation_green[4], correlation_red[4]]

# entropy = [entropy_blue[0], entropy_green[0], entropy_red[0],
#             entropy_blue[1], entropy_green[1], entropy_red[1],
#             entropy_blue[2], entropy_green[2], entropy_red[2],
#             entropy_blue[3], entropy_green[3], entropy_red[3],
#             entropy_blue[4], entropy_green[4], entropy_red[4]]
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\3797703563.py:46: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_contrast = [contrast_blue[0], contrast_green[0], contrast_red[0],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\3797703563.py:47: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   contrast_blue[1], contrast_green[1], contrast_red[1],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\3797703563.py:48: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   contrast_blue[2], contrast_green[2], contrast_red[2],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\3797703563.py:49: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   contrast_blue[3], contrast_green[3], contrast_red[3],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\3797703563.py:50: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   contrast_blue[4], contrast_green[4], contrast_red[4]]
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\3797703563.py:52: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_homogeneity = [homogeneity_blue[0], homogeneity_green[0], homogeneity_red[0],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\3797703563.py:53: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   homogeneity_blue[1], homogeneity_green[1], homogeneity_red[1],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\3797703563.py:54: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   homogeneity_blue[2], homogeneity_green[2], homogeneity_red[2],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\3797703563.py:55: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   homogeneity_blue[3], homogeneity_green[3], homogeneity_red[3],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\3797703563.py:56: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   homogeneity_blue[4], homogeneity_green[4], homogeneity_red[4]]
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\3797703563.py:64: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_energy = [energy_blue[0], energy_green[0], energy_red[0],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\3797703563.py:65: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   energy_blue[1], energy_green[1], energy_red[1],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\3797703563.py:66: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   energy_blue[2], energy_green[2], energy_red[2],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\3797703563.py:67: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   energy_blue[3], energy_green[3], energy_red[3],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\3797703563.py:68: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   energy_blue[4], energy_green[4], energy_red[4]]
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\3797703563.py:70: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_correlation = [correlation_blue[0], correlation_green[0], correlation_red[0],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\3797703563.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   correlation_blue[1], correlation_green[1], correlation_red[1],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\3797703563.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   correlation_blue[2], correlation_green[2], correlation_red[2],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\3797703563.py:73: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   correlation_blue[3], correlation_green[3], correlation_red[3],
# C:\Users\asus\AppData\Local\Temp\ipykernel_37712\3797703563.py:74: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   correlation_blue[4], correlation_green[4], correlation_red[4]]

# %%
# Tentukan nama file gambar
file_name = "std_deviation_barchart.png"

# Gabungkan folder dengan nama file untuk mendapatkan path lengkap
output_path = os.path.join(output_folder, file_name)


plt.figure(figsize=(15, 6))

# Offset untuk setiap kelompok bar
offset = 0.2

# Menggeser posisi setiap kelompok batang
plt.bar([pos - 1.5 * offset for pos in tick_positions], std_contrast, label='Contrast', color='blue', width=0.2)
plt.bar([pos - 0.5 * offset for pos in tick_positions], std_correlation, label='Correlation', color='green', width=0.2)
plt.bar([pos + 0.5 * offset for pos in tick_positions], std_energy, label='Energy', color='red', width=0.2)
plt.bar([pos + 1.5 * offset for pos in tick_positions], std_homogeneity, label='Homogenity', color='yellow', width=0.2)

plt.title('Susu Segar vs Campuran (GLCM Features)')
plt.ylabel('standard deviation values')
plt.grid(True, axis='y')  # Hanya menampilkan grid pada sumbu y
plt.xticks(tick_positions, x_labels, rotation=0)

# Menambahkan label konsentrasi di atas setiap batang
for i, concentration in enumerate(concentrations):
    plt.text(i * n_channels + 1, plt.ylim()[0] - 0.0029, concentration, ha='center', va='top', fontsize=10, fontweight='bold')

# Garis vertikal untuk memisahkan kelompok
for i in range(1, len(concentrations)):
    plt.axvline(x=i * n_channels - 0.5, color='black', linestyle='--', lw=1)

plt.legend(loc='best')
plt.tight_layout()
# menyimpan plot ke dalam file
plt.savefig(output_path, dpi=400)

plt.show()
